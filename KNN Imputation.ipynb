# %%
from tqdm.auto import tqdm
import numpy as np
from cache_decorator import Cache
import matplotlib.pyplot as plt
from repairing_genomic_gaps import build_multivariate_dataset_cae
from multiprocessing import cpu_count
from sklearn.impute import KNNImputer
# Out:
# /usr/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
window_size = 1000
batch_size = 100

train, test = build_multivariate_dataset_cae(window_size, batch_size=batch_size)

# %%
train.on_epoch_end()
train_x, train_y = train[0]

# %%
test.on_epoch_end()
test_x, test_y = test[0]

# %%
(train_x[:, window_size//2]==0.25).mean(), (test_x[:, window_size//2]==0.25).mean()
# Out:
# (1.0, 1.0)

# %%
imputer = KNNImputer(missing_values=0.25)
imputer.fit(train_y.reshape(-1, window_size*4))
# Out:
# KNNImputer(add_indicator=False, copy=True, metric='nan_euclidean',
#            missing_values=0.25, n_neighbors=5, weights='uniform')

# %%
train_pred_x = imputer.transform(train_x.reshape(-1, window_size*4))

# %%
test_pred_x = imputer.transform(test_x.reshape(-1, window_size*4))

# %%
test_pred_x = test_pred_x.reshape(-1, window_size, 4)

# %%
from sklearn.metrics import roc_auc_score, average_precision_score, accuracy_score

# %%
roc_auc_score(test_y[:, 500], test_pred_x[:, 500])
# Out:
# 0.5660533331074495

# %%
average_precision_score(test_y[:, 500], test_pred_x[:, 500])
# Out:
# 0.2969818531313464

# %%
accuracy_score(np.argmax(test_y[:, 500], axis=-1), np.argmax(test_pred_x[:, 500], axis=-1))
# Out:
# 0.33026666666666665

# %%
# Let X be an array containing missing values
from missingpy import MissForest
forest = MissForest(random_state=42, n_jobs=cpu_count()//2, missing_values=0.25, verbose=1)
forest.fit(train_y.reshape(-1, 1000*4))
# Out:
# MissForest(bootstrap=True, class_weight=None, copy=True,
#            criterion=('mse', 'gini'), decreasing=False, max_depth=None,
#            max_features='auto', max_iter=10, max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, missing_values=0.25, n_estimators=100,
#            n_jobs=20, oob_score=False, random_state=42, verbose=1,
#            warm_start=False)

# %%
forest_test_pred_x = forest.transform(np.vstack([test_x, train_y]).reshape(-1, 1000*4))
# Out:
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.3s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.2s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# [Parallel(n_jobs=20)]: Done  10 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=20)]: Done 100 out of 100 | elapsed:    0.0s finished
# [Parallel(n_jobs=20)]: Using backend ThreadingBackend with 20 concurrent workers.
# ...

# %%
roc_auc_score(test_y[:, 500], forest_test_pred_x[:, 500]), average_precision_score(test_y[:, 500], forest_test_pred_x[:, 500]), accuracy_score(np.argmax(test_y[:, 500], axis=-1), np.argmax(forest_test_pred_x[:, 500], axis=-1))
